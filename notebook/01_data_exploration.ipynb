# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

BASE_PATH = "../data/raw/Indian/"

# %%
classes = os.listdir(BASE_PATH)

filepaths = []
labels = []

for cls in classes:
    class_dir = os.path.join(BASE_PATH, cls)
    for img in os.listdir(class_dir):
        filepaths.append(os.path.join(class_dir, img))
        labels.append(cls)

print("Total images:", len(filepaths))
print("Total labels:", len(labels))
# Out:
# Total images: 42745
# Total labels: 42745

# %%
df = pd.DataFrame({
    "file_paths": filepaths,
    "labels": labels
})

df.head()
# Out:
#                       file_paths labels
# 0     ../data/raw/Indian/1\0.jpg      1
# 1     ../data/raw/Indian/1\1.jpg      1
# 2    ../data/raw/Indian/1\10.jpg      1
# 3   ../data/raw/Indian/1\100.jpg      1
# 4  ../data/raw/Indian/1\1000.jpg      1

# %%
df['labels'].value_counts()
# Out:
# labels
# C    1447
# O    1429
# I    1379
# V    1290
# Q    1200
# L    1200
# M    1200
# N    1200
# P    1200
# R    1200
# J    1200
# S    1200
# T    1200
# U    1200
# W    1200
# X    1200
# Y    1200
# K    1200
# 1    1200
# 2    1200
# H    1200
# G    1200
# F    1200
# E    1200
# D    1200
# B    1200
# A    1200
# 9    1200
# 8    1200
# 7    1200
# 6    1200
# 5    1200
# 4    1200
# 3    1200
# Z    1200
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    df, train_size=0.95, random_state=0, stratify=df['labels']
)

train_df, val_df = train_test_split(
    train_df, train_size=0.9, random_state=0, stratify=train_df['labels']
)

print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
# Out:
# Train: 36546
# Validation: 4061
# Test: 2138

# %%
os.makedirs("../data/processed", exist_ok=True)

train_df.to_csv("../data/processed/train.csv", index=False)
val_df.to_csv("../data/processed/val.csv", index=False)
test_df.to_csv("../data/processed/test.csv", index=False)
